# %%
import pandas as pd
import numpy as np
import math
from collections import Counter

n = 160

# %%
# Load the data
recipes = pd.read_csv("full_dataset.csv", nrows = n)

# User ingredients
user_ingredients = ['bite size shredded rice biscuits', 'brown sugar', 'milk', 'vanilla', 'nuts', 'butter', 'chicken', 'garlic', 'onion', 'pepper', 'salt', 'tomato', 'lemon']
#print (recipes)

recipe_ing = {}
recipe_dict = {}
for index, row in recipes.iterrows():
    #print (row['NER'])
    recipe_ing[index] = row['NER']
    recipe_dict[index] = row['title']

# %%
#standardize the format of each ingredient
def clean_ingredient(ingredient):
    ingredient = ingredient.lower()
    while ingredient[0] != "\"":
        ingredient = ingredient[1:]
    while ingredient[-1] != "\"":
        ingredient = ingredient[:-1]
    return ingredient[1:-1]

# %%
#get the unique ingredients and the frequency of each ingredient

ingredient_freq = Counter()

i = 0
add = True

all_ing = set()
for r in recipe_ing.values():
    for ing in r.split(','):
        ing = clean_ingredient(ing)
        ingredient_freq[ing] += 1
        all_ing.add(ing)
        if ing == '+':
            add = False
    if add:
        i += 1
all_ing = sorted(list(all_ing))
print(len(all_ing), len(ingredient_freq))
ingredient_freq = sorted(ingredient_freq.items(), key=lambda x: x[0])

print(recipe_ing[159])

# Print the sorted ingredients and their frequencies
print(i)
# Out:
# 372 372
# ["white cake mix", "+", "pistachio instant pudding", "ginger ale", "eggs", "pecans", "cool whip", "milk", "pistachio instant pudding"]
# 159

# %%
#calculate wieghts for each ingredient

ingredient_weights = {}
for ing, freq in ingredient_freq:
    ingredient_weights[ing] = math.log(n/(freq + 1))
print(ingredient_weights)
# Out:
# {'+': 4.382026634673881, 'alfalfa honey': 4.382026634673881, 'allspice': 4.382026634673881, 'almond extract': 3.9765615265657175, 'almonds': 3.9765615265657175, 'american cheese': 4.382026634673881, 'angel': 4.382026634673881, 'apple': 3.9765615265657175, 'apple juice': 4.382026634673881, 'apple vinegar': 4.382026634673881, 'apples': 3.4657359027997265, 'applesauce': 4.382026634673881, 'apricot jello': 4.382026634673881, 'apricot nectar': 4.382026634673881, 'arborio': 4.382026634673881, 'armour dried beef': 4.382026634673881, 'artichokes': 4.382026634673881, 'bacon': 3.6888794541139363, 'baking potatoes': 4.382026634673881, 'baking powder': 2.8779492378976075, 'baking soda': 3.9765615265657175, 'bananas': 3.4657359027997265, 'barbecue sauce': 4.382026634673881, 'basil': 3.6888794541139363, 'bay leaf': 3.6888794541139363, 'beans': 3.283414346005772, 'beef': 3.6888794541139363, 'beef bouillon': 4.382026634673881, 'beef consomme': 4.382026634673881, 'beef stock': 3.9765615265657175, 'beer': 4.382026634673881, 'bell pepper': 3.4657359027997265, 'bell peppers': 4.382026634673881, 'bisquick': 4.382026634673881, 'bite': 4.382026634673881, 'bite size shredded rice biscuits': 4.382026634673881, 'black olives': 3.9765615265657175, 'black pepper': 3.4657359027997265, 'blueberries': 4.382026634673881, 'boiling water': 3.6888794541139363, 'brandy': 4.382026634673881, 'bread': 3.9765615265657175, 'broccoli': 3.6888794541139363, 'broccoli flowerets': 4.382026634673881, 'brown sugar': 2.367123614131617, 'butter': 1.6411866107486806, 'butter beans': 3.9765615265657175, 'buttermilk': 3.283414346005772, 'cabbage': 3.9765615265657175, 'cake': 4.382026634673881, 'cake mix': 3.9765615265657175, 'cake yeast': 4.382026634673881, "campbell's cream": 4.382026634673881, 'caramel topping': 4.382026634673881, 'carrot chunks': 4.382026634673881, 'carrots': 3.283414346005772, 'cashews': 4.382026634673881, 'catsup': 3.6888794541139363, 'cauliflower': 3.9765615265657175, 'celery': 2.8779492378976075, 'celery salt': 4.382026634673881, 'cereal': 4.382026634673881, 'cheddar cheese': 2.436116485618568, 'cheese': 3.6888794541139363, 'cherries': 4.382026634673881, 'cherry pie mix': 4.382026634673881, 'chicken': 2.302585092994046, 'chicken breasts': 3.9765615265657175, 'chicken broth': 3.9765615265657175, 'chicken cutlets': 4.382026634673881, 'chicken gravy': 4.382026634673881, 'chicken stock': 4.382026634673881, 'chili powder': 4.382026634673881, 'chinese noodles': 4.382026634673881, 'chocolate chips': 3.4657359027997265, 'chocolate fudge cake': 4.382026634673881, 'chocolate fudge pudding': 4.382026634673881, 'chocolate pudding': 4.382026634673881, 'chocolate syrup': 4.382026634673881, 'chunk white chicken': 4.382026634673881, 'cider vinegar': 4.382026634673881, 'cinnamon': 2.772588722239781, 'cleaned strawberries': 4.382026634673881, 'clove garlic': 3.6888794541139363, 'cloves': 4.382026634673881, 'club soda': 4.382026634673881, 'clump': 4.382026634673881, 'cocoa': 3.4657359027997265, 'coconut': 3.6888794541139363, 'cold water': 3.9765615265657175, 'condensed milk': 3.283414346005772, 'confectioners sugar': 4.382026634673881, 'consomme': 4.382026634673881, 'cooking oats': 4.382026634673881, 'cooking oil': 4.382026634673881, 'cool whip': 4.382026634673881, 'corn': 4.382026634673881, 'corn bread': 4.382026634673881, 'corn flake crumbs': 4.382026634673881, 'corn tortilla': 4.382026634673881, 'corned beef': 3.6888794541139363, 'cornflakes': 4.382026634673881, 'cornstarch': 3.283414346005772, 'cottage cheese': 4.382026634673881, 'crackers': 3.9765615265657175, 'cranberries': 4.382026634673881, 'cranberry sauce': 4.382026634673881, 'cream': 4.382026634673881, 'cream cheese': 2.0794415416798357, 'cream of celery soup': 3.4657359027997265, 'cream of chicken': 4.382026634673881, 'cream of chicken soup': 2.995732273553991, 'cream of mushroom soup': 2.995732273553991, 'cream-style': 4.382026634673881, 'cream-style corn': 3.9765615265657175, 'crescent rolls': 3.97656152656571 ...

# %%
def create_vector(recipe):
    vector = []
    for ingredient in all_ing:
        if(ingredient in recipe):
            vector.append(ingredient_weights[ingredient])
        else:
            vector.append(0)
    return vector

# %%
# Encode the recipes
recipe_vectors = {}
i = 0
for ingredients in recipe_ing.items():
    recipe_vectors[recipe_dict[i]] = create_vector(ingredients[1])
    i += 1
user_vector = create_vector(user_ingredients)

# %%
def cos_sim(a, b):
    #dot product
    dot_product = sum([i * j for i, j in zip(a, b)])

    #magnitude of the vectors
    magnitude_vec1 = math.sqrt(sum(i ** 2 for i in a))
    magnitude_vec2 = math.sqrt(sum(j ** 2 for j in b))
    if magnitude_vec1 == 0 or magnitude_vec2 == 0:  # Handle zero vectors
        return 0
    return dot_product / (magnitude_vec1 * magnitude_vec2)

# %%
def weighted_cos_sim(a, b):
    # Compute weighted dot product
    a = [float(ai) for ai in a]
    b = [float(bi) for bi in b]
    weights = [float(ingredient_weights[w]) for w in ingredient_weights]

    dot_product = sum([w * ai * bi for ai, bi, w in zip(a, b, weights)])

    # Compute weighted magnitudes
    magnitude_a = math.sqrt(sum([w * ai**2 for ai, w in zip(a, weights)]))
    magnitude_b = math.sqrt(sum([w * bi**2 for bi, w in zip(b, weights)]))

    # Handle the case where either magnitude is zero (no common ingredients)
    if magnitude_a == 0 or magnitude_b == 0:
        return 0.0
    
    # Return the weighted cosine similarity
    return dot_product / (magnitude_a * magnitude_b)

# %%
similarities = {}
for recipe, vector in recipe_vectors.items():
    similarity = weighted_cos_sim(user_vector, vector)
    similarities[recipe] = similarity

recipe_scores = sorted(similarities.items(), key=lambda x: x[1], reverse=True)

print("Recommendations:")
for recipe, score in recipe_scores:
    print(f"{recipe}: {score:.4f}")
# Out:
# Recommendations:
# No-Bake Nut Cookies: 0.4560
# Cheese Dip: 0.3501
# Prize-Winning Meat Loaf: 0.2856
# Spaghetti Sauce To Can: 0.2812
# Nolan'S Pepper Steak: 0.2769
# Zucchini-Artichoke Continental: 0.2407
# Chicken Stew: 0.2394
# Corral Barbecued Beef Steak Strips: 0.2301
# Quick Coffee Cake(6 Servings)  : 0.2140
# French Onion Soup: 0.2098
# Eggplant Spaghetti Sauce: 0.2040
# Creole Flounder: 0.1971
# Taco Salad Chip Dip: 0.1969
# Supreme Beef Casserole: 0.1879
# Casserole Italiano: 0.1877
# Jan'S Winter Soup: 0.1789
# Vegetable Soup: 0.1724
# Vegetable-Burger Soup: 0.1697
# Spanish Hamburgers: 0.1645
# Smoked Turkey Risotto: 0.1608
# Pecan Pralines: 0.1582
# Chicken Spaghetti: 0.1568
# Creamy Corn: 0.1540
# Egg Casserole: 0.1442
# Sweet-N-Sour Chicken: 0.1362
# Chicken Salad: 0.1355
# Baked Beans: 0.1348
# Cuddy Farms Marinated Turkey: 0.1285
# Monkey Bread: 0.1257
# Easy Fudge: 0.1237
# Fast Real Good Fudge: 0.1214
# Ranch Beef And Beans: 0.1209
# Consomme Chicken: 0.1184
# Creamy Coleslaw(Better Homes And Gardens)  : 0.1176
# Summer Chicken: 0.1160
# Tater Tot Casserole: 0.1038
# Pound Cake: 0.1033
# Easy Chocolate Frosting: 0.1031
# Fruit Pizza: 0.1009
# Potato And Cheese Pie: 0.0992
# Cold Spaghetti Salad: 0.0979
# Cheeseburger Potato Soup: 0.0974
# Rhubarb Coffee Cake: 0.0971
# Dream Pie: 0.0936
# Cutout Cookie: 0.0929
# Grandma Hanrath'S Banana Breadfort Collins, Colorado  : 0.0921
# Crustless Vegetable Ham Pie: 0.0904
# Quick Peppermint Puffs: 0.0898
# Magic Cookie Bars: 0.0871
# Dot'S Civil War Cake: 0.0867
# German Potato Salad: 0.0863
# Chicken Pot Pie: 0.0855
# Chocolate Peanut Butter Cake: 0.0831
# Pineapple Nut Pie: 0.0818
# Pancakes: 0.0777
# Quick Barbecue Wings: 0.0772
# Scalloped Corn: 0.0743
# Taco-Filled Green Pepper: 0.0729
# Moist Devil'S Food Cake: 0.0728
# Divinity Fudge: 0.0724
# Squash Casserole: 0.0705
# Pasta Chicken Salad(268 Calories Per Serving)  : 0.0659
# Egg Drop Soup: 0.0656
# Cheese Ball: 0.0629
# Chicken Roll-Ups: 0.0598
# Annie'S Diabetic Candy: 0.0596
# Smothered Round Steak(Servings: 4)  : 0.0581
# Red Cabbage And Apples: 0.0576
# Chicken Ole: 0.0573
# Cranberry-Apple-Orange Salad: 0.0571
# Potato Casserole: 0.0570
# Forever Amber: 0.0556
# Chicken Divan: 0.0556
# Eggless Milkless Applesauce Cake: 0.0549
# Chocolate Pie: 0.0548
# Chicken Casserole: 0.0544
# Mexican Cookie Rings: 0.0533
# One Hour Rolls: 0.0531
# Apricot Dessert: 0.0525
# Bright Party Beans: 0.0508
# Crisp Oatmeal Cookies: 0.0507
# Chess Pie: 0.0505
# Cherry Pizza: 0.0497
# Jewell Ball'S Chicken: 0.0492
# Puppy Chow: 0.0474
# Bonbon Cookies: 0.0468
# Cranberry Salad: 0.0458
# Sesame Ginger Chicken: 0.0450
# Gooey Coffee Cake: 0.0448
# Vanilla Creme Dessert: 0.0442
# Angel Biscuits: 0.0437
# St. Joseph'S Zeppole: 0.0421
# Mulled Cider: 0.0405
# Chocolate "Stuff": 0.0401
# Frozen Peach Mousse: 0.0380
# Crazy Peanut Butter Cookies: 0.0377
# Chicken Funny: 0.0377
# Good Sweet Muffins: 0.0364
# Funnel Cake: 0.0358
# Pink Stuff(Frozen Dessert)  : 0.0283
# Baked French Toast: 0.0262
# *Apricot Salad: 0.0241
# Cucumber Salad With Dill: 0.0235
# Millionaire Pie: 0.0224
# Brickle Bars: 0.0207
# No Bake Pumpkin Pie: 0.0201
# Corn "Oysters": 0.0197
# 7-Up Cake: 0.0197
# Beef And Spanish Rice Casserole: 0.0178
# Tuna Macaroni Casserole: 0.0177
# Broccoli Salad: 0.0174
# Buckeye Candy: 0.0169
# Caramel Pie: 0.0168
# Brown Rice: 0.0158
# Reeses Cups(Candy)  : 0.0158
# Souper Tuna Crunch: 0.0157
# Watergate Cake: 0.0153
# Dill Dip: 0.0150
# Cheese-Ham Ball: 0.0149
# Broccoli Cornbread: 0.0146
# Tamale Casserole: 0.0142
# Taco Dip: 0.0141
# Corned Beef And Cabbage Casserole: 0.0134
# Corned Beef Dip: 0.0121
# Apple Pie: 0.0087
# Bonnie'S Bread: 0.0061
# Sloppy Joes: 0.0056
# Apple Crisp: 0.0055
# Fresh Strawberry Pie: 0.0046
# Double Cherry Delight: 0.0000
# Easy German Chocolate Cake: 0.0000
# Strawberry Whatever: 0.0000
# Chocolate Frango Mints: 0.0000
# Punch Bowl Fruit Salad: 0.0000
# Artichoke Dip: 0.0000
# Broccoli Dip For Crackers: 0.0000
# Summer Spaghetti: 0.0000
# Pear-Lime Salad: 0.0000
# Watermelon Rind Pickles: 0.0000
# Chocolate Mint Bars: 0.0000
# Beer Bread: 0.0000
# Three Bean Salad: 0.0000
# Dave'S Corn Casserole: 0.0000
# Crab Cakes: 0.0000
# Phylis' Pineapple-Banana Salad: 0.0000
# Strawberry Pie: 0.0000
# Blueberry Surprise: 0.0000
# Sausage Balls: 0.0000
# Ambrosia: 0.0000
# Microwave Spice Tea: 0.0000
# Barbecue Noodle Cheese Bake: 0.0000
# Don Juan'S Sangria: 0.0000
# Pistachio Salad: 0.0000
# Honey Almond Squares: 0.0000
# Blackberry Pie: 0.0000
